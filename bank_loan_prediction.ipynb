# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilmerai/ml_basic/blob/master/bank_loan_predication.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

bank = pd.read_csv("bank.csv")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
bank.head()
# Out:
#    ID  Age  Experience  ...  CD Account  Online  CreditCard
# 0   1   25           1  ...           0       0           0
# 1   2   45          19  ...           0       0           0
# 2   3   39          15  ...           0       0           0
# 3   4   35           9  ...           0       0           0
# 4   5   35           8  ...           0       0           1
#
# [5 rows x 14 columns]

# %%
bank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  5000 non-null   int64
#  1   Age                 5000 non-null   int64
#  2   Experience          5000 non-null   int64
#  3   Income              5000 non-null   int64
#  4   ZIP Code            5000 non-null   int64
#  5   Family              5000 non-null   int64
#  6   CCAvg               5000 non-null   float64
#  7   Education           5000 non-null   int64
#  8   Mortgage            5000 non-null   int64
#  9   Personal Loan       5000 non-null   int64
#  10  Securities Account  5000 non-null   int64
#  11  CD Account          5000 non-null   int64
#  12  Online              5000 non-null   int64
#  13  CreditCard          5000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 547.0 KB

# %%
bank.dtypes
# Out:
# ID                      int64
# Age                     int64
# Experience              int64
# Income                  int64
# ZIP Code                int64
# Family                  int64
# CCAvg                 float64
# Education               int64
# Mortgage                int64
# Personal Loan           int64
# Securities Account      int64
# CD Account              int64
# Online                  int64
# CreditCard              int64
# dtype: object

# %%
bank.describe().transpose()
# Out:
#                      count          mean  ...       75%      max
# ID                  5000.0   2500.500000  ...   3750.25   5000.0
# Age                 5000.0     45.338400  ...     55.00     67.0
# Experience          5000.0     20.104600  ...     30.00     43.0
# Income              5000.0     73.774200  ...     98.00    224.0
# ZIP Code            5000.0  93152.503000  ...  94608.00  96651.0
# Family              5000.0      2.396400  ...      3.00      4.0
# CCAvg               5000.0      1.937938  ...      2.50     10.0
# Education           5000.0      1.881000  ...      3.00      3.0
# Mortgage            5000.0     56.498800  ...    101.00    635.0
# Personal Loan       5000.0      0.096000  ...      0.00      1.0
# Securities Account  5000.0      0.104400  ...      0.00      1.0
# CD Account          5000.0      0.060400  ...      0.00      1.0
# Online              5000.0      0.596800  ...      1.00      1.0
# ...

# %%
bank.describe().transpose()
# Out:
#                      count          mean  ...       75%      max
# ID                  5000.0   2500.500000  ...   3750.25   5000.0
# Age                 5000.0     45.338400  ...     55.00     67.0
# Experience          5000.0     20.119600  ...     30.00     43.0
# Income              5000.0     73.774200  ...     98.00    224.0
# ZIP Code            5000.0  93152.503000  ...  94608.00  96651.0
# Family              5000.0      2.396400  ...      3.00      4.0
# CCAvg               5000.0      1.937938  ...      2.50     10.0
# Education           5000.0      1.881000  ...      3.00      3.0
# Mortgage            5000.0     56.498800  ...    101.00    635.0
# Personal Loan       5000.0      0.096000  ...      0.00      1.0
# Securities Account  5000.0      0.104400  ...      0.00      1.0
# CD Account          5000.0      0.060400  ...      0.00      1.0
# Online              5000.0      0.596800  ...      1.00      1.0
# ...

# %%
bank.apply(lambda x : sum(x.isnull()) )
# Out:
# ID                    0
# Age                   0
# Experience            0
# Income                0
# ZIP Code              0
# Family                0
# CCAvg                 0
# Education             0
# Mortgage              0
# Personal Loan         0
# Securities Account    0
# CD Account            0
# Online                0
# CreditCard            0
# dtype: int64

# %%
bank.apply(lambda x: len(x.unique()))
# Out:
# ID                    5000
# Age                     45
# Experience              47
# Income                 162
# ZIP Code               467
# Family                   4
# CCAvg                  108
# Education                3
# Mortgage               347
# Personal Loan            2
# Securities Account       2
# CD Account               2
# Online                   2
# CreditCard               2
# dtype: int64

# %%
bank[bank <0] =0

# %%
import math
median_Experience = math.floor(bank.Experience.median())
median_Experience
# Out:
# 20

# %%
bank.Experience = bank.Experience.fillna(median_Experience)
bank.head()
# Out:
#    ID  Age  Experience  ...  CD Account  Online  CreditCard
# 0   1   25           1  ...           0       0           0
# 1   2   45          19  ...           0       0           0
# 2   3   39          15  ...           0       0           0
# 3   4   35           9  ...           0       0           0
# 4   5   35           8  ...           0       0           1
#
# [5 rows x 14 columns]

# %%
corr = bank.corr()

# %%
corr
# Out:
#                           ID       Age  ...    Online  CreditCard
# ID                  1.000000 -0.008473  ... -0.002528    0.017028
# Age                -0.008473  1.000000  ...  0.013702    0.007681
# Experience         -0.008265  0.994198  ...  0.013975    0.008910
# Income             -0.017695 -0.055269  ...  0.014206   -0.002385
# ZIP Code            0.013432 -0.029216  ...  0.016990    0.007691
# Family             -0.016797 -0.046418  ...  0.010354    0.011588
# CCAvg              -0.024675 -0.052012  ... -0.003611   -0.006689
# Education           0.021463  0.041334  ... -0.015004   -0.011014
# Mortgage           -0.013920 -0.012539  ... -0.005995   -0.007231
# Personal Loan      -0.024801 -0.007726  ...  0.006278    0.002802
# Securities Account -0.016972 -0.000436  ...  0.012627   -0.015028
# CD Account         -0.006909  0.008043  ...  0.175880    0.278644
# Online             -0.002528  0.013702  ...  1.000000    0.004210
# ...

# %%
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth": 2.5})
plt.figure(figsize=(15,7))
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask, 1)] = True
a = sns.heatmap(corr,mask=mask, annot=True, fmt='.2f')
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=90)
roty = a.set_yticklabels(a.get_yticklabels(), rotation=30)

# %%
plt.figure(figsize=(15,5))

sns.distplot(bank.Age  ,color="r")

# %%
plt.figure(figsize=(20,6))
sns.lineplot(x="Age" , y="Personal Loan" , hue="Family" ,data=bank  )

# %%
plt.figure(figsize=(20,6))
sns.lineplot(x="Age" , y="Mortgage" , hue="Family" ,data=bank  )

# %%
variant = bank[["Experience","Income","Mortgage"]].groupby(bank.Age).sum()
variant.plot(kind='line', fontsize = 14, figsize=(18,5))

# %%
plt.figure(figsize=(17,5))
sns.lineplot(x="Age" , y="Income" ,hue="Family" ,data=bank)

# %%
sns.factorplot('Age','Income',data=bank,
                   hue='Family',
                   size=15,
                   aspect=0.7,
                   palette='Blues',
                   join=False,
              )
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:3672: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
bank.drop(["ID"],axis=1,inplace=True)

# %%
bank.head()
# Out:
#    Age  Experience  Income  ...  CD Account  Online  CreditCard
# 0   25           1      49  ...           0       0           0
# 1   45          19      34  ...           0       0           0
# 2   39          15      11  ...           0       0           0
# 3   35           9     100  ...           0       0           0
# 4   35           8      45  ...           0       0           1
#
# [5 rows x 13 columns]

# %%
X = bank.drop("Personal Loan",axis=1)

# %%
y = bank["Personal Loan"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_prediction = logmodel.predict(X_test)

# %%
y_prediction
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test,y_prediction)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.93      0.98      0.95      1351\n           1       0.57      0.30      0.39       149\n\n    accuracy                           0.91      1500\n   macro avg       0.75      0.64      0.67      1500\nweighted avg       0.89      0.91      0.89      1500\n'

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_prediction)
# Out:
# array([[1318,   33],
#        [ 105,   44]])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
loan_entropy = DecisionTreeClassifier(criterion="entropy" , random_state=2000 , max_depth=5 , min_samples_leaf=5 )
loan_entropy.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=5, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2000, splitter='best')

# %%
loan_classifier = DecisionTreeClassifier(max_leaf_nodes=5,random_state=2000)
loan_classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=5,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2000, splitter='best')

# %%
y_pre = loan_classifier.predict(X_test)

# %%
Y_predi = loan_entropy.predict(X_test)
Y_predi
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_pre
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pre)
# Out:
# 0.9775

# %%
accuracy_score(y_test,Y_predi)
# Out:
# 0.982

# %%
confusion_matrix(y_test,y_pre)
# Out:
# array([[1799,    9],
#        [  36,  156]])

# %%
confusion_matrix(y_test,Y_predi)
# Out:
# array([[1796,   12],
#        [  24,  168]])
